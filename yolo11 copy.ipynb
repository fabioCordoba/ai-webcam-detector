# %% [markdown]
# 4. Afinación de YOLO11 (detección) con el dataset
# Para poder acceder al modelo pre-entrenado debemos comenzar instalando la librería "ultralytics":

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in d:\backend\ai-webcam-detector\venv\lib\site-packages (8.4.7)
# Requirement already satisfied: numpy>=1.23.0 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from ultralytics) (2.4.1)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from ultralytics) (4.13.0.90)
# Requirement already satisfied: pillow>=7.1.2 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from ultralytics) (12.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from ultralytics) (1.17.0)
# Requirement already satisfied: torch<2.10,>=1.8.0 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from ultralytics) (2.9.1)
# Requirement already satisfied: torchvision>=0.9.0 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from ultralytics) (0.24.1)
# Requirement already satisfied: psutil>=5.8.0 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from ultralytics) (7.2.1)
# Requirement already satisfied: polars>=0.20.0 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from ultralytics) (1.37.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: filelock in d:\backend\ai-webcam-detector\venv\lib\site-packages (from torch<2.10,>=1.8.0->ultralytics) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from torch<2.10,>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from torch<2.10,>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from torch<2.10,>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from torch<2.10,>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from torch<2.10,>=1.8.0->ultralytics) (2026.1.0)
# Requirement already satisfied: setuptools in d:\backend\ai-webcam-detector\venv\lib\site-packages (from torch<2.10,>=1.8.0->ultralytics) (80.10.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=3 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.37.1 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from polars>=0.20.0->ultralytics) (1.37.1)
# Requirement already satisfied: six>=1.5 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from sympy>=1.13.3->torch<2.10,>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\backend\ai-webcam-detector\venv\lib\site-packages (from jinja2->torch<2.10,>=1.8.0->ultralytics) (3.0.3)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO

# 1. Cargar el modelo (nano, el más pequeño)
model = YOLO("yolo11n.pt")
preds = model('datasets/dataset_vehiculos/images/test2')
# Out:
# image 1/1 d:\BACKEND\ai-webcam-detector\datasets\dataset_vehiculos\images\test2\depositphotos_115262096-stock-photo-traffic-on-calle-5-in.jpg: 448x640 8 cars, 1 truck, 39.2ms
# Speed: 1.2ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Mostrar predicciones
preds[0].show()
